# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000,high = 90.000,size = 2000)
lngs = np.random.uniform(low = -90.000,high = 90.000,size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 771

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(2)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #Current_Description = city_weather["weather"]["description"]
        #weather_dict = {
                       # "City":city_weather["name"],
                        #"Country": city_weather["sys"]["country"], 
                        #"Lat":city_weather["coord"]["lat"], 
                        #"Lng":city_weather["coord"]["lon"], 
                        #"Max Temp":city_weather["main"]["temp_max"], 
                        #"Humidity":city_weather["main"]["humidity"],  
                        #"Cloudiness": city_weather["clouds"]["all"], 
                        #"Wind Speed": city_weather["wind"]["speed"],  
                        #"Current Description":city_weather["weather"]["description"]}
           
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Min Temp": city_min_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
                          #"Current Description":Current_Description})
                          
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 1 | kars
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | sept-iles
# Processing Record 7 of Set 1 | ilulissat
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | pangody
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | ipira
# Processing Record 17 of Set 1 | buraydah
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | akdepe
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | verkhnyaya toyma
# Processing Record 22 of Set 1 | biograd na moru
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | camopi
# Processing Record 25 of Set 1 | kutno
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | grindavik
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | kudahuvadhoo
# Processing Record 31 of Set 1 | colomi
# Processing Record 32 of Set 1 | grand gaube
# Processing Record 33 of Set 1 | porto santo
# Processing Record 34 of Set 1 | kindu
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | vangaindrano
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | ampanihy
# Processing Record 40 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 1 | caravelas
# Processing Record 42 of Set 1 | viedma
# Processing Record 43 of Set 1 | zaragoza
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | kamenka
# Processing Record 48 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 1 | forestville
# Processing Record 50 of Set 1 | walvis bay
# Processing Record 1 of Set 2 | tandil
# Processing Record 2 of Set 2 | kavaratti
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | limoges
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | ostrovnoy
# Processing Record 7 of Set 2 | copiapo
# Processing Record 8 of Set 2 | mizdah
# Processing Record 9 of Set 2 | bardiyah
# Processing Record 10 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | chemnitz
# Processing Record 15 of Set 2 | sidi bu zayd
# City not found. Skipping...
# Processing Record 16 of Set 2 | sabha
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | la solana
# Processing Record 24 of Set 2 | novo aripuana
# Processing Record 25 of Set 2 | itapirapua
# Processing Record 26 of Set 2 | mbigou
# Processing Record 27 of Set 2 | corn island
# Processing Record 28 of Set 2 | marrakesh
# Processing Record 29 of Set 2 | altay
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | manzil bu ruqaybah
# City not found. Skipping...
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | chapais
# Processing Record 35 of Set 2 | georgiyevka
# Processing Record 36 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 37 of Set 2 | goderich
# Processing Record 38 of Set 2 | santa cruz cabralia
# Processing Record 39 of Set 2 | camacha
# Processing Record 40 of Set 2 | tambura
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | vicuna
# Processing Record 44 of Set 2 | la palma
# Processing Record 45 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 47 of Set 2 | bonito
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | maceio
# Processing Record 50 of Set 2 | oistins
# Processing Record 1 of Set 3 | menongue
# Processing Record 2 of Set 3 | pivijay
# Processing Record 3 of Set 3 | pimentel
# Processing Record 4 of Set 3 | lukaya
# Processing Record 5 of Set 3 | botwood
# Processing Record 6 of Set 3 | paamiut
# Processing Record 7 of Set 3 | nawa
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | pushkino
# Processing Record 10 of Set 3 | bonthe
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | sovetskiy
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | intipuca
# Processing Record 15 of Set 3 | berbera
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | araguacu
# Processing Record 18 of Set 3 | fredericksburg
# Processing Record 19 of Set 3 | valdivia
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | santa rosa
# Processing Record 23 of Set 3 | baijiantan
# Processing Record 24 of Set 3 | conceicao das alagoas
# Processing Record 25 of Set 3 | la peca
# Processing Record 26 of Set 3 | dunmore town
# Processing Record 27 of Set 3 | bakchar
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | maarianhamina
# Processing Record 30 of Set 3 | fort-shevchenko
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | ancud
# Processing Record 34 of Set 3 | sorland
# Processing Record 35 of Set 3 | tsabong
# Processing Record 36 of Set 3 | nouadhibou
# Processing Record 37 of Set 3 | leh
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | razdolnoye
# Processing Record 40 of Set 3 | oksfjord
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | riyadh
# Processing Record 43 of Set 3 | sao raimundo nonato
# Processing Record 44 of Set 3 | coquimbo
# Processing Record 45 of Set 3 | malumfashi
# Processing Record 46 of Set 3 | waddan
# Processing Record 47 of Set 3 | rio gallegos
# Processing Record 48 of Set 3 | kosice
# Processing Record 49 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 3 | capaci
# Processing Record 1 of Set 4 | souillac
# Processing Record 2 of Set 4 | adrar
# Processing Record 3 of Set 4 | salzkotten
# Processing Record 4 of Set 4 | chimbote
# Processing Record 5 of Set 4 | morondava
# Processing Record 6 of Set 4 | abha
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | hamilton
# Processing Record 9 of Set 4 | iquitos
# Processing Record 10 of Set 4 | krosno
# Processing Record 11 of Set 4 | beira
# Processing Record 12 of Set 4 | laguna
# Processing Record 13 of Set 4 | balkhash
# Processing Record 14 of Set 4 | kaduqli
# Processing Record 15 of Set 4 | herat
# Processing Record 16 of Set 4 | salinas
# Processing Record 17 of Set 4 | saint-augustin
# Processing Record 18 of Set 4 | samana
# Processing Record 19 of Set 4 | cobourg
# Processing Record 20 of Set 4 | iberia
# Processing Record 21 of Set 4 | campina grande do sul
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | acari
# Processing Record 24 of Set 4 | sao jose da coroa grande
# Processing Record 25 of Set 4 | itacarambi
# Processing Record 26 of Set 4 | chardara
# Processing Record 27 of Set 4 | skelleftea
# Processing Record 28 of Set 4 | jalu
# Processing Record 29 of Set 4 | kinston
# Processing Record 30 of Set 4 | soloneshnoye
# Processing Record 31 of Set 4 | scarborough
# Processing Record 32 of Set 4 | axim
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | gamba
# Processing Record 35 of Set 4 | codrington
# Processing Record 36 of Set 4 | cockburn town
# Processing Record 37 of Set 4 | wadi musa
# Processing Record 38 of Set 4 | condoto
# Processing Record 39 of Set 4 | vila velha
# Processing Record 40 of Set 4 | roald
# Processing Record 41 of Set 4 | cabedelo
# Processing Record 42 of Set 4 | maragogi
# Processing Record 43 of Set 4 | floro
# Processing Record 44 of Set 4 | santona
# Processing Record 45 of Set 4 | kant
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 4 | shakiso
# Processing Record 49 of Set 4 | boca do acre
# Processing Record 50 of Set 4 | dubti
# Processing Record 1 of Set 5 | aketi
# Processing Record 2 of Set 5 | marienburg
# Processing Record 3 of Set 5 | san andres
# Processing Record 4 of Set 5 | port-gentil
# Processing Record 5 of Set 5 | san bartolome de tirajana
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | uyuni
# Processing Record 8 of Set 5 | melito di porto salvo
# Processing Record 9 of Set 5 | pisco
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | belmonte
# Processing Record 12 of Set 5 | inirida
# Processing Record 13 of Set 5 | mazara del vallo
# Processing Record 14 of Set 5 | taoudenni
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | chipinge
# Processing Record 17 of Set 5 | adamovka
# Processing Record 18 of Set 5 | pandhana
# Processing Record 19 of Set 5 | carutapera
# Processing Record 20 of Set 5 | salym
# Processing Record 21 of Set 5 | irtyshskiy
# Processing Record 22 of Set 5 | bandarbeyla
# Processing Record 23 of Set 5 | farafangana
# Processing Record 24 of Set 5 | bathsheba
# Processing Record 25 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 5 | omboue
# Processing Record 27 of Set 5 | qaanaaq
# Processing Record 28 of Set 5 | dvinskoy
# Processing Record 29 of Set 5 | ramkola
# Processing Record 30 of Set 5 | castro
# Processing Record 31 of Set 5 | bell ville
# Processing Record 32 of Set 5 | goundam
# Processing Record 33 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 5 | maputo
# Processing Record 35 of Set 5 | sharkan
# Processing Record 36 of Set 5 | tessalit
# Processing Record 37 of Set 5 | altamira
# Processing Record 38 of Set 5 | ponta delgada
# Processing Record 39 of Set 5 | den helder
# Processing Record 40 of Set 5 | skopin
# Processing Record 41 of Set 5 | annapolis
# Processing Record 42 of Set 5 | kedrovyy
# Processing Record 43 of Set 5 | tabuk
# Processing Record 44 of Set 5 | shadegan
# Processing Record 45 of Set 5 | puerto carreno
# Processing Record 46 of Set 5 | hammerfest
# Processing Record 47 of Set 5 | san rafael del sur
# Processing Record 48 of Set 5 | sakakah
# Processing Record 49 of Set 5 | jeremie
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | kulhudhuffushi
# Processing Record 3 of Set 6 | thunder bay
# Processing Record 4 of Set 6 | lasa
# Processing Record 5 of Set 6 | inhambane
# Processing Record 6 of Set 6 | mithimna
# City not found. Skipping...
# Processing Record 7 of Set 6 | opuwo
# Processing Record 8 of Set 6 | profondeville
# Processing Record 9 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 6 | yarada
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | mahendragarh
# Processing Record 13 of Set 6 | larsnes
# Processing Record 14 of Set 6 | nantucket
# Processing Record 15 of Set 6 | mandali
# Processing Record 16 of Set 6 | korla
# Processing Record 17 of Set 6 | monrovia
# Processing Record 18 of Set 6 | dingle
# Processing Record 19 of Set 6 | santa marta
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | santa barbara
# Processing Record 22 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 6 | cerro san antonio
# City not found. Skipping...
# Processing Record 24 of Set 6 | karmana
# City not found. Skipping...
# Processing Record 25 of Set 6 | portland
# Processing Record 26 of Set 6 | santiago del estero
# Processing Record 27 of Set 6 | soyo
# Processing Record 28 of Set 6 | tabas
# Processing Record 29 of Set 6 | bahir dar
# Processing Record 30 of Set 6 | sechura
# Processing Record 31 of Set 6 | san juan
# Processing Record 32 of Set 6 | lidkoping
# Processing Record 33 of Set 6 | el playon
# Processing Record 34 of Set 6 | hambantota
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | bodoco
# City not found. Skipping...
# Processing Record 37 of Set 6 | mahibadhoo
# Processing Record 38 of Set 6 | puerto del rosario
# Processing Record 39 of Set 6 | bilma
# Processing Record 40 of Set 6 | aleksandrovskoye
# Processing Record 41 of Set 6 | najran
# Processing Record 42 of Set 6 | bodden town
# Processing Record 43 of Set 6 | praia da vitoria
# Processing Record 44 of Set 6 | prestice
# Processing Record 45 of Set 6 | bereda
# Processing Record 46 of Set 6 | zhanaozen
# Processing Record 47 of Set 6 | kismayo
# Processing Record 48 of Set 6 | terre-de-bas
# Processing Record 49 of Set 6 | kidal
# Processing Record 50 of Set 6 | yenagoa
# Processing Record 1 of Set 7 | talnakh
# Processing Record 2 of Set 7 | virginia beach
# Processing Record 3 of Set 7 | paracatu
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | dodoma
# Processing Record 6 of Set 7 | concepcion
# Processing Record 7 of Set 7 | sinazongwe
# Processing Record 8 of Set 7 | san vicente de canete
# Processing Record 9 of Set 7 | longyearbyen
# Processing Record 10 of Set 7 | muros
# Processing Record 11 of Set 7 | igarka
# Processing Record 12 of Set 7 | ronneby
# Processing Record 13 of Set 7 | marzuq
# Processing Record 14 of Set 7 | arroio grande
# Processing Record 15 of Set 7 | teeli
# Processing Record 16 of Set 7 | aquiraz
# Processing Record 17 of Set 7 | guarapuava
# Processing Record 18 of Set 7 | astana
# Processing Record 19 of Set 7 | vidalia
# Processing Record 20 of Set 7 | sao joao do paraiso
# Processing Record 21 of Set 7 | lapao
# Processing Record 22 of Set 7 | edgewater
# Processing Record 23 of Set 7 | tilhar
# Processing Record 24 of Set 7 | tucurui
# Processing Record 25 of Set 7 | pucallpa
# Processing Record 26 of Set 7 | kasama
# Processing Record 27 of Set 7 | moose factory
# Processing Record 28 of Set 7 | pardilho
# Processing Record 29 of Set 7 | coruripe
# Processing Record 30 of Set 7 | danville
# Processing Record 31 of Set 7 | raga
# Processing Record 32 of Set 7 | kuryk
# Processing Record 33 of Set 7 | klaksvik
# Processing Record 34 of Set 7 | saint-francois
# Processing Record 35 of Set 7 | raudeberg
# Processing Record 36 of Set 7 | ondjiva
# Processing Record 37 of Set 7 | tazovskiy
# Processing Record 38 of Set 7 | togul
# Processing Record 39 of Set 7 | arauca
# Processing Record 40 of Set 7 | bousse
# Processing Record 41 of Set 7 | marsa matruh
# Processing Record 42 of Set 7 | iisaku
# Processing Record 43 of Set 7 | valparaiso
# Processing Record 44 of Set 7 | wattegama
# Processing Record 45 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 47 of Set 7 | sokoni
# Processing Record 48 of Set 7 | teodoro sampaio
# Processing Record 49 of Set 7 | agadir
# Processing Record 50 of Set 7 | meulaboh
# Processing Record 1 of Set 8 | obera
# Processing Record 2 of Set 8 | vestmannaeyjar
# Processing Record 3 of Set 8 | les cayes
# Processing Record 4 of Set 8 | sansepolcro
# Processing Record 5 of Set 8 | yelanskiy
# Processing Record 6 of Set 8 | mercedes
# Processing Record 7 of Set 8 | sur
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | polyarnyy
# Processing Record 10 of Set 8 | boende
# Processing Record 11 of Set 8 | hobyo
# Processing Record 12 of Set 8 | sinnamary
# Processing Record 13 of Set 8 | wajir
# Processing Record 14 of Set 8 | rundu
# Processing Record 15 of Set 8 | spasskoye
# Processing Record 16 of Set 8 | san borja
# Processing Record 17 of Set 8 | keti bandar
# Processing Record 18 of Set 8 | derzhavinsk
# Processing Record 19 of Set 8 | idukki
# Processing Record 20 of Set 8 | kommunisticheskiy
# Processing Record 21 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 8 | vallenar
# Processing Record 23 of Set 8 | road town
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | mangrol
# Processing Record 26 of Set 8 | bereznik
# Processing Record 27 of Set 8 | colares
# Processing Record 28 of Set 8 | lethem
# Processing Record 29 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 8 | contamana
# Processing Record 31 of Set 8 | arroyo
# Processing Record 32 of Set 8 | harvard
# Processing Record 33 of Set 8 | changji
# Processing Record 34 of Set 8 | lebu
# Processing Record 35 of Set 8 | richards bay
# Processing Record 36 of Set 8 | havre-saint-pierre
# Processing Record 37 of Set 8 | chake chake
# Processing Record 38 of Set 8 | berlevag
# Processing Record 39 of Set 8 | xapuri
# Processing Record 40 of Set 8 | lamu
# Processing Record 41 of Set 8 | araouane
# Processing Record 42 of Set 8 | vila do maio
# Processing Record 43 of Set 8 | zapolyarnyy
# Processing Record 44 of Set 8 | pinega
# Processing Record 45 of Set 8 | berezovka
# Processing Record 46 of Set 8 | olafsvik
# Processing Record 47 of Set 8 | trogir
# Processing Record 48 of Set 8 | hadejia
# Processing Record 49 of Set 8 | berekua
# Processing Record 50 of Set 8 | brae
# Processing Record 1 of Set 9 | madinat sittah uktubar
# Processing Record 2 of Set 9 | kargil
# Processing Record 3 of Set 9 | tambovka
# Processing Record 4 of Set 9 | zomin
# Processing Record 5 of Set 9 | chokwe
# Processing Record 6 of Set 9 | hauterive
# Processing Record 7 of Set 9 | khandbari
# Processing Record 8 of Set 9 | riberalta
# Processing Record 9 of Set 9 | kunya
# Processing Record 10 of Set 9 | ambilobe
# Processing Record 11 of Set 9 | stornoway
# Processing Record 12 of Set 9 | muisne
# Processing Record 13 of Set 9 | marsh harbour
# Processing Record 14 of Set 9 | shushtar
# Processing Record 15 of Set 9 | kathu
# Processing Record 16 of Set 9 | shannon
# Processing Record 17 of Set 9 | loubomo
# Processing Record 18 of Set 9 | mogadishu
# Processing Record 19 of Set 9 | stoughton
# Processing Record 20 of Set 9 | saint-leu
# Processing Record 21 of Set 9 | kipini
# Processing Record 22 of Set 9 | akdagmadeni
# Processing Record 23 of Set 9 | skjervoy
# Processing Record 24 of Set 9 | calvinia
# Processing Record 25 of Set 9 | murgab
# Processing Record 26 of Set 9 | karaton
# Processing Record 27 of Set 9 | puta
# Processing Record 28 of Set 9 | carnarvon
# Processing Record 29 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 9 | sabang
# Processing Record 31 of Set 9 | dhadar
# Processing Record 32 of Set 9 | virovitica
# Processing Record 33 of Set 9 | serebryansk
# Processing Record 34 of Set 9 | marawi
# Processing Record 35 of Set 9 | iskateley
# Processing Record 36 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 37 of Set 9 | save
# Processing Record 38 of Set 9 | shache
# Processing Record 39 of Set 9 | sumbe
# Processing Record 40 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 9 | kalamare
# Processing Record 42 of Set 9 | garmsar
# Processing Record 43 of Set 9 | samfya
# Processing Record 44 of Set 9 | parsabad
# Processing Record 45 of Set 9 | surt
# Processing Record 46 of Set 9 | tubuala
# Processing Record 47 of Set 9 | filadelfia
# Processing Record 48 of Set 9 | savelugu
# Processing Record 49 of Set 9 | chateau-thierry
# Processing Record 50 of Set 9 | misratah
# Processing Record 1 of Set 10 | ornskoldsvik
# Processing Record 2 of Set 10 | mwingi
# Processing Record 3 of Set 10 | comodoro rivadavia
# Processing Record 4 of Set 10 | vilhena
# Processing Record 5 of Set 10 | pangnirtung
# Processing Record 6 of Set 10 | mineros
# Processing Record 7 of Set 10 | nueva guinea
# Processing Record 8 of Set 10 | stepnogorsk
# Processing Record 9 of Set 10 | puerto el triunfo
# Processing Record 10 of Set 10 | kiruna
# Processing Record 11 of Set 10 | seia
# Processing Record 12 of Set 10 | nazca
# Processing Record 13 of Set 10 | yanaul
# Processing Record 14 of Set 10 | goya
# Processing Record 15 of Set 10 | malanje
# Processing Record 16 of Set 10 | vila franca do campo
# Processing Record 17 of Set 10 | zholymbet
# Processing Record 18 of Set 10 | kerman
# Processing Record 19 of Set 10 | goure
# Processing Record 20 of Set 10 | brokopondo
# Processing Record 21 of Set 10 | bubaque
# Processing Record 22 of Set 10 | chililabombwe
# Processing Record 23 of Set 10 | zhezkazgan
# Processing Record 24 of Set 10 | luau
# Processing Record 25 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 10 | sambava
# Processing Record 27 of Set 10 | patna
# Processing Record 28 of Set 10 | kalmunai
# Processing Record 29 of Set 10 | buenaventura
# Processing Record 30 of Set 10 | nuuk
# Processing Record 31 of Set 10 | chigorodo
# Processing Record 32 of Set 10 | kimparana
# Processing Record 33 of Set 10 | gengenbach
# Processing Record 34 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 35 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 10 | krasnoye
# Processing Record 37 of Set 10 | san vicente
# Processing Record 38 of Set 10 | saint-joseph
# Processing Record 39 of Set 10 | pinheiro machado
# Processing Record 40 of Set 10 | kirkwood
# Processing Record 41 of Set 10 | axintele
# Processing Record 42 of Set 10 | coihaique
# Processing Record 43 of Set 10 | svetlyy
# Processing Record 44 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 45 of Set 10 | dover
# Processing Record 46 of Set 10 | anuradhapura
# Processing Record 47 of Set 10 | mecca
# Processing Record 48 of Set 10 | makariv
# Processing Record 49 of Set 10 | santarem
# Processing Record 50 of Set 10 | pitimbu
# Processing Record 1 of Set 11 | bella union
# Processing Record 2 of Set 11 | abalak
# Processing Record 3 of Set 11 | mumford
# Processing Record 4 of Set 11 | nicoya
# Processing Record 5 of Set 11 | rincon
# Processing Record 6 of Set 11 | rudraprayag
# Processing Record 7 of Set 11 | sunndalsora
# Processing Record 8 of Set 11 | oranjestad
# Processing Record 9 of Set 11 | krasnoborsk
# Processing Record 10 of Set 11 | urucara
# Processing Record 11 of Set 11 | hazleton
# Processing Record 12 of Set 11 | tyukhtet
# Processing Record 13 of Set 11 | quatre cocos
# Processing Record 14 of Set 11 | aksay
# Processing Record 15 of Set 11 | polunochnoye
# Processing Record 16 of Set 11 | ballstad
# City not found. Skipping...
# Processing Record 17 of Set 11 | thetford mines
# Processing Record 18 of Set 11 | aksarka
# Processing Record 19 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 11 | tres arroyos
# Processing Record 22 of Set 11 | leczyca
# Processing Record 23 of Set 11 | taltal
# Processing Record 24 of Set 11 | rehoboth
# Processing Record 25 of Set 11 | dudinka
# Processing Record 26 of Set 11 | san pedro
# Processing Record 27 of Set 11 | atar
# Processing Record 28 of Set 11 | banda aceh
# Processing Record 29 of Set 11 | bollnas
# Processing Record 30 of Set 11 | glenluce
# Processing Record 31 of Set 11 | kitgum
# Processing Record 32 of Set 11 | sistranda
# Processing Record 33 of Set 11 | sao jose do belmonte
# Processing Record 34 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 11 | krasnoslobodsk
# Processing Record 36 of Set 11 | ferkessedougou
# Processing Record 37 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 11 | imbituba
# Processing Record 39 of Set 11 | gurupi
# Processing Record 40 of Set 11 | warri
# Processing Record 41 of Set 11 | maridi
# Processing Record 42 of Set 11 | iralaya
# Processing Record 43 of Set 11 | at-bashi
# Processing Record 44 of Set 11 | mabaruma
# Processing Record 45 of Set 11 | jacareacanga
# Processing Record 46 of Set 11 | elizabeth city
# Processing Record 47 of Set 11 | leshukonskoye
# Processing Record 48 of Set 11 | dharchula
# Processing Record 49 of Set 11 | kyrylivka
# Processing Record 50 of Set 11 | boa vista
# Processing Record 1 of Set 12 | sawakin
# Processing Record 2 of Set 12 | beisfjord
# Processing Record 3 of Set 12 | camana
# Processing Record 4 of Set 12 | kamina
# Processing Record 5 of Set 12 | itarema
# Processing Record 6 of Set 12 | kita
# Processing Record 7 of Set 12 | kushmurun
# Processing Record 8 of Set 12 | cartagena del chaira
# Processing Record 9 of Set 12 | clearwater
# Processing Record 10 of Set 12 | karasjok
# Processing Record 11 of Set 12 | troyes
# Processing Record 12 of Set 12 | makat
# Processing Record 13 of Set 12 | ostrowiec swietokrzyski
# Processing Record 14 of Set 12 | trelew
# Processing Record 15 of Set 12 | alta floresta
# Processing Record 16 of Set 12 | conde
# Processing Record 17 of Set 12 | san cristobal
# Processing Record 18 of Set 12 | ashqelon
# Processing Record 19 of Set 12 | havoysund
# Processing Record 20 of Set 12 | bom jesus da lapa
# Processing Record 21 of Set 12 | marystown
# Processing Record 22 of Set 12 | betafo
# Processing Record 23 of Set 12 | sanary-sur-mer
# Processing Record 24 of Set 12 | tall kayf
# Processing Record 25 of Set 12 | santa maria
# Processing Record 26 of Set 12 | urdoma
# Processing Record 27 of Set 12 | turbat
# Processing Record 28 of Set 12 | umm kaddadah
# Processing Record 29 of Set 12 | bolshevik
# Processing Record 30 of Set 12 | manta
# Processing Record 31 of Set 12 | jega
# Processing Record 32 of Set 12 | strezhevoy
# Processing Record 33 of Set 12 | berkovica
# Processing Record 34 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | malinovoye ozero
# Processing Record 36 of Set 12 | killybegs
# Processing Record 37 of Set 12 | abhar
# Processing Record 38 of Set 12 | mathathane
# Processing Record 39 of Set 12 | aranos
# Processing Record 40 of Set 12 | george
# Processing Record 41 of Set 12 | tornio
# Processing Record 42 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 12 | sfantu gheorghe
# Processing Record 44 of Set 12 | warrington
# Processing Record 45 of Set 12 | hazorasp
# Processing Record 46 of Set 12 | westport
# Processing Record 47 of Set 12 | beyneu
# Processing Record 48 of Set 12 | zaysan
# Processing Record 49 of Set 12 | balkanabat
# Processing Record 50 of Set 12 | koulamoutou
# Processing Record 1 of Set 13 | yomou
# Processing Record 2 of Set 13 | yanam
# Processing Record 3 of Set 13 | uppsala
# Processing Record 4 of Set 13 | troy
# Processing Record 5 of Set 13 | hajnowka
# Processing Record 6 of Set 13 | huarmey
# Processing Record 7 of Set 13 | sao domingos do maranhao
# Processing Record 8 of Set 13 | montpellier
# Processing Record 9 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 10 of Set 13 | rumuruti
# Processing Record 11 of Set 13 | tiznit
# Processing Record 12 of Set 13 | puerto narino
# Processing Record 13 of Set 13 | le vauclin
# Processing Record 14 of Set 13 | montepuez
# Processing Record 15 of Set 13 | puerto padre
# Processing Record 16 of Set 13 | wabash
# Processing Record 17 of Set 13 | yabrud
# Processing Record 18 of Set 13 | yar-sale
# Processing Record 19 of Set 13 | mezen
# Processing Record 20 of Set 13 | bonfim
# Processing Record 21 of Set 13 | abu samrah
# Processing Record 22 of Set 13 | barranca
# Processing Record 23 of Set 13 | tunoshna
# Processing Record 24 of Set 13 | cochrane
# Processing Record 25 of Set 13 | yala
# Processing Record 26 of Set 13 | gonbad-e qabus
# Processing Record 27 of Set 13 | nagua
# Processing Record 28 of Set 13 | heidelberg
# Processing Record 29 of Set 13 | rudbar
# Processing Record 30 of Set 13 | fria
# Processing Record 31 of Set 13 | lages
# Processing Record 32 of Set 13 | bethanien
# Processing Record 33 of Set 13 | umm bab
# Processing Record 34 of Set 13 | inyonga
# Processing Record 35 of Set 13 | santana
# Processing Record 36 of Set 13 | stromness
# Processing Record 37 of Set 13 | andenes
# Processing Record 38 of Set 13 | el badari
# City not found. Skipping...
# Processing Record 39 of Set 13 | san alberto
# Processing Record 40 of Set 13 | ipswich
# Processing Record 41 of Set 13 | puerto colombia
# Processing Record 42 of Set 13 | horasan
# Processing Record 43 of Set 13 | sabratah
# Processing Record 44 of Set 13 | tarko-sale
# Processing Record 45 of Set 13 | teguise
# Processing Record 46 of Set 13 | diffa
# Processing Record 47 of Set 13 | saquena
# Processing Record 48 of Set 13 | velyka pysarivka
# Processing Record 49 of Set 13 | padre paraiso
# Processing Record 50 of Set 13 | humaita
# Processing Record 1 of Set 14 | kelo
# Processing Record 2 of Set 14 | manturovo
# Processing Record 3 of Set 14 | ikot ekpene
# Processing Record 4 of Set 14 | macamic
# Processing Record 5 of Set 14 | bandar-e lengeh
# Processing Record 6 of Set 14 | tonekabon
# Processing Record 7 of Set 14 | alice town
# Processing Record 8 of Set 14 | aripuana
# Processing Record 9 of Set 14 | oranjemund
# Processing Record 10 of Set 14 | sokoto
# Processing Record 11 of Set 14 | wana
# Processing Record 12 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 14 | doha
# Processing Record 14 of Set 14 | aswan
# Processing Record 15 of Set 14 | kapan
# Processing Record 16 of Set 14 | mao
# Processing Record 17 of Set 14 | kambove
# Processing Record 18 of Set 14 | karamadai
# Processing Record 19 of Set 14 | morales
# Processing Record 20 of Set 14 | kutum
# Processing Record 21 of Set 14 | zhanakorgan
# Processing Record 22 of Set 14 | larkana
# Processing Record 23 of Set 14 | volot
# Processing Record 24 of Set 14 | fontainebleau
# Processing Record 25 of Set 14 | presidencia roque saenz pena
# Processing Record 26 of Set 14 | kahta
# Processing Record 27 of Set 14 | verkhnyaya inta
# Processing Record 28 of Set 14 | belebey
# Processing Record 29 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 30 of Set 14 | slobidka
# Processing Record 31 of Set 14 | cotonou
# Processing Record 32 of Set 14 | kusa
# Processing Record 33 of Set 14 | bar harbor
# Processing Record 34 of Set 14 | whitehaven
# Processing Record 35 of Set 14 | porto walter
# Processing Record 36 of Set 14 | dakar
# Processing Record 37 of Set 14 | lundazi
# Processing Record 38 of Set 14 | ploemeur
# Processing Record 39 of Set 14 | sheopur
# Processing Record 40 of Set 14 | guane
# Processing Record 41 of Set 14 | oyem
# Processing Record 42 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 14 | saedinenie
# Processing Record 44 of Set 14 | minna
# Processing Record 45 of Set 14 | cordele
# Processing Record 46 of Set 14 | tabat
# Processing Record 47 of Set 14 | ayorou
# Processing Record 48 of Set 14 | mikhaylovka
# Processing Record 49 of Set 14 | vieques
# Processing Record 50 of Set 14 | gat
# Processing Record 1 of Set 15 | abeokuta
# Processing Record 2 of Set 15 | kuito
# Processing Record 3 of Set 15 | katesh
# Processing Record 4 of Set 15 | anloga
# Processing Record 5 of Set 15 | sarakhs
# Processing Record 6 of Set 15 | presidente venceslau
# Processing Record 7 of Set 15 | maraa
# Processing Record 8 of Set 15 | dutse
# Processing Record 9 of Set 15 | kyshtovka
# Processing Record 10 of Set 15 | lahij
# Processing Record 11 of Set 15 | teguldet
# Processing Record 12 of Set 15 | agarak
# Processing Record 13 of Set 15 | fram
# Processing Record 14 of Set 15 | jawhar
# Processing Record 15 of Set 15 | bogorodskoye
# Processing Record 16 of Set 15 | yuzhnyy
# Processing Record 17 of Set 15 | dalbandin
# Processing Record 18 of Set 15 | dzaoudzi
# Processing Record 19 of Set 15 | aksu
# Processing Record 20 of Set 15 | wilmington
# Processing Record 21 of Set 15 | luanda
# Processing Record 22 of Set 15 | merrill
# Processing Record 23 of Set 15 | kondinskoye
# Processing Record 24 of Set 15 | trairi
# Processing Record 25 of Set 15 | szamotuly
# Processing Record 26 of Set 15 | sable-sur-sarthe
# Processing Record 27 of Set 15 | namanga
# Processing Record 28 of Set 15 | gobabis
# Processing Record 29 of Set 15 | luena
# Processing Record 30 of Set 15 | tokmak
# Processing Record 31 of Set 15 | ouadda
# Processing Record 32 of Set 15 | cassilandia
# Processing Record 33 of Set 15 | eyemouth
# Processing Record 34 of Set 15 | jalingo
# Processing Record 35 of Set 15 | uray
# Processing Record 36 of Set 15 | muzhi
# Processing Record 37 of Set 15 | qaqortoq
# Processing Record 38 of Set 15 | awbari
# Processing Record 39 of Set 15 | catio
# Processing Record 40 of Set 15 | norway
# Processing Record 41 of Set 15 | kemi
# Processing Record 42 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 43 of Set 15 | vabalninkas
# Processing Record 44 of Set 15 | springbok
# Processing Record 45 of Set 15 | garissa
# Processing Record 46 of Set 15 | tefe
# Processing Record 47 of Set 15 | sredec
# City not found. Skipping...
# Processing Record 48 of Set 15 | havlickuv brod
# Processing Record 49 of Set 15 | reinosa
# Processing Record 50 of Set 15 | nara
# Processing Record 1 of Set 16 | wetter
# Processing Record 2 of Set 16 | puerto madryn
# Processing Record 3 of Set 16 | stryn
# Processing Record 4 of Set 16 | mbekenyera
# Processing Record 5 of Set 16 | bara
# Processing Record 6 of Set 16 | homa bay
# Processing Record 7 of Set 16 | detva
# Processing Record 8 of Set 16 | nieuw amsterdam
# Processing Record 9 of Set 16 | limenaria
# Processing Record 10 of Set 16 | hagere selam
# Processing Record 11 of Set 16 | santa cruz del sur
# Processing Record 12 of Set 16 | la rioja
# Processing Record 13 of Set 16 | san severino marche
# Processing Record 14 of Set 16 | pervomayskoye
# Processing Record 15 of Set 16 | bad hersfeld
# Processing Record 16 of Set 16 | sudova vyshnya
# Processing Record 17 of Set 16 | naregal
# Processing Record 18 of Set 16 | kabo
# Processing Record 19 of Set 16 | coulihaut
# City not found. Skipping...
# Processing Record 20 of Set 16 | lovozero
# Processing Record 21 of Set 16 | takoradi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 716

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Min Temp  Humidity  \
# 0             Kars  40.6020  43.0950    284.40    284.40        54
# 1  Bambous Virieux -20.3428  57.7575    295.49    295.49        67
# 2           Namibe -15.1961  12.1522    295.25    295.25        76
# 3      Henties Bay -22.1160  14.2845    289.87    289.87        83
# 4        Sept-Iles  50.2001 -66.3821    280.38    280.38        68
# 5        Ilulissat  69.2167 -51.1000    272.16    272.16        64
# 6          Ushuaia -54.8000 -68.3000    283.96    282.94        43
# 7     Ponta Do Sol  32.6667 -17.1000    297.66    297.50        56
# 8   Ribeira Grande  38.5167 -28.7000    296.37    296.37        78
# 9          Pangody  65.8500  74.4859    277.01    277.01        91
#
#    Cloudiness  Wind Speed Country                 Date
# 0          20        4.12      TR  2022-10-11 15:06:38
# 1           5        5.35      MU  2022-10-11 15:07:53
# 2          69        5.55      AO  2022-10-11 15:07:57
# 3          11        7.06      NA  2022-10-11 15:07:57
# 4         100        8.11      CA  2022-10-11 15:07:58
# 5          75        1.54      GL  2022-10-11 15:07:58
# 6          75        4.63      AR  2022-10-11 15:07:59
# 7           8        1.89      PT  2022-10-11 15:07:59
# 8          20        3.09      PT  2022-10-11 15:07:59
# 9         100        4.81      RU  2022-10-11 15:08:00

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Min Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = pd.DataFrame(city_data, columns = ["City","Country","Lat","Lng","Max Temp","Min Temp","Humidity","Cloudiness","Wind Speed","Date"])

# Recreate the DataFrame by using the new column order
#city_data_df = city_data_df(new_column_order)

# Display sample data
new_column_order
# Out:
#                 City Country      Lat      Lng  Max Temp  Min Temp  Humidity  \
# 0               Kars      TR  40.6020  43.0950    284.40    284.40        54
# 1    Bambous Virieux      MU -20.3428  57.7575    295.49    295.49        67
# 2             Namibe      AO -15.1961  12.1522    295.25    295.25        76
# 3        Henties Bay      NA -22.1160  14.2845    289.87    289.87        83
# 4          Sept-Iles      CA  50.2001 -66.3821    280.38    280.38        68
# ..               ...     ...      ...      ...       ...       ...       ...
# 711   Sudova Vyshnya      UA  49.7889  23.3722    288.05    288.05        76
# 712          Naregal      IN  15.5833  75.8167    297.02    297.02        85
# 713             Kabo      CF   7.6994  18.6290    298.87    298.87        77
# 714         Lovozero      RU  68.0050  35.0117    278.61    278.61        87
# 715         Takoradi      GH   4.8845  -1.7554    300.60    300.60        72
#
#      Cloudiness  Wind Speed                 Date
# 0            20        4.12  2022-10-11 15:06:38
# 1             5        5.35  2022-10-11 15:07:53
# 2            69        5.55  2022-10-11 15:07:57
# 3            11        7.06  2022-10-11 15:07:57
# 4           100        8.11  2022-10-11 15:07:58
# ..          ...         ...                  ...
# 711         100        3.26  2022-10-11 15:17:06
# 712         100        2.74  2022-10-11 15:17:06
# 713          98        2.09  2022-10-11 15:17:07
# 714         100        3.50  2022-10-11 15:17:08
# 715          96        3.85  2022-10-11 15:17:08
#
# [716 rows x 10 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
new_column_order.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Min Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Date           object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "cities.csv"

# Export the city_data DataFrame into a CSV file
new_column_order.to_csv(output_data_file, index_label="City_ID")
